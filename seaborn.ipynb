# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("dm_office_sales.csv")
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
#  4   salary              1000 non-null   int64
#  5   sales               1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
sns.pairplot(df, hue="training level")
# Out:
# d:\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # DESCRIPTION(Visualisation) UNIVARIEE
# Univariée Numerique

# %%
sns.boxplot(x='work experience', data=df)
# Out:
# <Axes: xlabel='work experience'>

# %%
sns.violinplot(x='work experience', data=df)
# Out:
# <Axes: xlabel='work experience'>

# %%
sns.kdeplot(x='work experience', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='Density'>

# %% [markdown]
# # DESCRIPTION(Visualisation) UNIVARIEE
# Univariée Catégorielle

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='level of education', data=df)
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
sns.catplot(x='division', data=df)
# Out:
# d:\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # DESCRIPTION(Visualisation) BIVARIEE
# Bivariée x=Numerique, y=Numerique

# %%
sns.kdeplot(x='work experience', y='salary', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>

# %%
sns.lineplot(x='work experience', y='salary', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>

# %%
sns.displot(x='work experience', y='salary', data=df)
# Out:
# d:\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(x='work experience', y='salary', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>

# %%
sns.stripplot(x='work experience', y='salary', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>

# %%
sns.pointplot(x='work experience', y='salary', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>

# %%
sns.boxplot(x='work experience', y='salary', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>

# %% [markdown]
# # CORRELATION (entre deux variables numeriques)

# %%
sns.heatmap(df[['work experience','salary']].corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # REGRESSION LINEAIRE

# %%
sns.regplot(x='work experience', y='salary', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>

# %% [markdown]
# # REGRESSION LINEAIRE
# 2 variables numerique et variable catégorielle ou num

# %%
sns.lmplot(x='work experience', y='salary', row='level of education', data=df)
# Out:
# d:\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x='work experience', y='salary', col='level of education', data=df)
# Out:
# d:\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # DESCRIPTION(Visualisation) BIVARIEE
# Bivariée  x= Catégorielle, y= Numerique

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x='level of education', y='salary', data=df)
# Out:
# <Axes: xlabel='level of education', ylabel='salary'>

# %% [markdown]
# # 2 Variable num et variable catégorielle ou num (nuage de point)

# %%
sns.relplot(x='work experience', y='salary', row='level of education', data=df)
# Out:
# d:\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # NUAGE DE POINT(pour tous les variables ) pour 2 variable num

# %%
sns.scatterplot(x='work experience', y='salary', hue='division', data=df)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>

# %%
dfprinters=df[df['division']=='printers']

# %%
sns.boxplot(x='work experience', y='salary', data=dfprinters)
plt.title('boxplot pour les division printer')
plt.show()

# %%
sns.pointplot(x='work experience', y='salary', data=dfprinters)
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>
